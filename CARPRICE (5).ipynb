# %% [markdown]
# ELIAZAR  RODRIGUEZ VELASCO
#
# GUSTAVO REYES ROMERO
#
# DE JESUS CABRARA CARLOS ARMANDO
#
# INGENIERIA EN DESARROLLO Y GESTION DE SOFTWARE
#
# 1718110990
#
# 1718110984
#
# 1718110382
# GRUPO 91

# %% [markdown]
# REGRESION LINEAL DE CARPRICE

# %%
import numpy as np
import pandas as pd
#regresion
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from joblib import dump,load
from sklearn.metrics import r2_score
#graficos
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt


#Asignar estilo a graficos de seaborns
sns.set_theme(style="darkgrid", palette="Spectral")

# %% [markdown]
# PARA CARGAR EL DATAFRAME
#
# subimos el archivo csv y luego usamos el siguiente codigo

# %%
df= pd.read_csv("car_price_assignment.csv")

# %% [markdown]
#  shape nos va a devolver una tupla con la cantidad de registros y la cantidad de columnas por registro

# %%
df.shape
# Out:
# (232, 26)

# %% [markdown]
# 5 PRIMEROS Y ULTIMOS REGISTROS

# %%
df.head(5)
# Out:
#   car_ID symboling                   CarName  ... citympg highwaympg    price
# 0      1         3        alfa-romero giulia  ...    21.0       27.0  13495.0
# 1      2         3       alfa-romero stelvio  ...    21.0       27.0  16500.0
# 2      3         1  alfa-romero Quadrifoglio  ...    19.0       26.0  16500.0
# 3      4         2               audi 100 ls  ...    24.0       30.0  13950.0
# 4      5         2                audi 100ls  ...    18.0       22.0  17450.0
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#     car_ID                  symboling  ... highwaympg price
# 227     22                 horsepower  ...        NaN   NaN
# 228     23                    peakrpm  ...        NaN   NaN
# 229     24                    citympg  ...        NaN   NaN
# 230     25                 highwaympg  ...        NaN   NaN
# 231     26  price(Dependent variable)  ...        NaN   NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# TIPO DE DATOS DE CADA COLUMNA

# %%
df.dtypes
# Out:
# car_ID               object
# symboling            object
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight          float64
# enginetype           object
# cylindernumber       object
# enginesize          float64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower          float64
# peakrpm             float64
# citympg             float64
# highwaympg          float64
# price               float64
# dtype: object

# %% [markdown]
# ELIMINAR REGISTROS DUPLICADOS

# %%
df.shape
# Out:
# (232, 26)

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (232, 26)

# %% [markdown]
# VALORES NULOS

# %%
df.isnull().sum()
# Out:
# car_ID               0
# symboling            0
# CarName              0
# fueltype            27
# aspiration          27
# doornumber          27
# carbody             27
# drivewheel          27
# enginelocation      27
# wheelbase           27
# carlength           27
# carwidth            27
# carheight           27
# curbweight          27
# enginetype          27
# cylindernumber      27
# enginesize          27
# fuelsystem          27
# boreratio           27
# stroke              27
# compressionratio    27
# horsepower          27
# peakrpm             27
# citympg             27
# highwaympg          27
# price               27
# dtype: int64

# %% [markdown]
# ELIMINAR VALORES INCOMPLETOS

# %%
df.count()
# Out:
# car_ID              232
# symboling           232
# CarName             232
# fueltype            205
# aspiration          205
# doornumber          205
# carbody             205
# drivewheel          205
# enginelocation      205
# wheelbase           205
# carlength           205
# carwidth            205
# carheight           205
# curbweight          205
# enginetype          205
# cylindernumber      205
# enginesize          205
# fuelsystem          205
# boreratio           205
# stroke              205
# compressionratio    205
# horsepower          205
# peakrpm             205
# citympg             205
# highwaympg          205
# price               205
# dtype: int64

# %% [markdown]
# Para borrar esos registros que no tienen datos, registros que tienen "datos no disponibles" usamos dropna

# %%
df = df.dropna()
df.count()
# Out:
# car_ID              205
# symboling           205
# CarName             205
# fueltype            205
# aspiration          205
# doornumber          205
# carbody             205
# drivewheel          205
# enginelocation      205
# wheelbase           205
# carlength           205
# carwidth            205
# carheight           205
# curbweight          205
# enginetype          205
# cylindernumber      205
# enginesize          205
# fuelsystem          205
# boreratio           205
# stroke              205
# compressionratio    205
# horsepower          205
# peakrpm             205
# citympg             205
# highwaympg          205
# price               205
# dtype: int64

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
sns.displot(df['price'], color='blue', kde=True)
sns.displot(dft, color='red', kde=True)

# %% [markdown]
# SEPARACION DE LAS COLUMNAS POR CATEGORIA

# %%
def categorical(dataframe):
  categori_c = []
  for c in df:
    if (df[c].dtype) == 'object':
      categori_c.append(c)

  return categori_c

# %%
categori_c = categorical(df)
print(categori_c)
# Out:
# ['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber', 'fuelsystem']

# %% [markdown]
# COLUMNAS NUMERICAS

# %%
def num(df):
  num_c = []
  for c in df:
    if df[c].dtype != 'object':
      num_c.append(c)
  return num_c

# %%
#mostrar columnas numericas
num_c = num(df)
print(num_c)
# Out:
# ['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price']

# %%
sns.displot(df['price'], color='red')

# %%
sns.displot(df['horsepower'], color='red')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    object
#  1   symboling         205 non-null    object
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    float64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# CATEGORICAS A NUMERICAS

# %%
pd.get_dummies(df, columns=['fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation', 'wheelbase', 'enginetype', 'cylindernumber', 'fuelsystem'], drop_first=False)
# Out:
#     car_ID symboling  ... fuelsystem_spdi  fuelsystem_spfi
# 0        1         3  ...               0                0
# 1        2         3  ...               0                0
# 2        3         1  ...               0                0
# 3        4         2  ...               0                0
# 4        5         2  ...               0                0
# ..     ...       ...  ...             ...              ...
# 200    201        -1  ...               0                0
# 201    202        -1  ...               0                0
# 202    203        -1  ...               0                0
# 203    204        -1  ...               0                0
# 204    205        -1  ...               0                0
#
# [205 rows x 107 columns]

# %% [markdown]
# PROMEDIO DE CADA UNA DE LAS COLUMNAS

# %%
df.mean()
# Out:
# car_ID                       inf
# wheelbase           9.875659e+01
# carlength           1.740493e+02
# carwidth            6.590780e+01
# carheight           5.372488e+01
# curbweight          2.555566e+03
# enginesize          1.269073e+02
# boreratio           3.329756e+00
# stroke              3.255415e+00
# compressionratio    1.014254e+01
# horsepower          1.041171e+02
# peakrpm             5.125122e+03
# citympg             2.521951e+01
# highwaympg          3.075122e+01
# price               1.327671e+04
# dtype: float64

# %% [markdown]
# CORRELACION ENTRE COLUMNAS

# %%
df.corr()
# Out:
#                   wheelbase  carlength  ...  highwaympg     price
# wheelbase          1.000000   0.874587  ...   -0.544082  0.577816
# carlength          0.874587   1.000000  ...   -0.704662  0.682920
# carwidth           0.795144   0.841118  ...   -0.677218  0.759325
# carheight          0.589435   0.491029  ...   -0.107358  0.119336
# curbweight         0.776386   0.877728  ...   -0.797465  0.835305
# enginesize         0.569329   0.683360  ...   -0.677470  0.874145
# boreratio          0.488750   0.606454  ...   -0.587012  0.553173
# stroke             0.160959   0.129533  ...   -0.043931  0.079443
# compressionratio   0.249786   0.158414  ...    0.265201  0.067984
# horsepower         0.353294   0.552623  ...   -0.770544  0.808139
# peakrpm           -0.360469  -0.287242  ...   -0.054275 -0.085267
# citympg           -0.470414  -0.670909  ...    0.971337 -0.685751
# highwaympg        -0.544082  -0.704662  ...    1.000000 -0.697599
# ...

# %% [markdown]
# MAPA DE CALOR

# %%
correlaciones= df.corr()
sns.heatmap(correlaciones)
correlaciones
# Out:
#                   wheelbase  carlength  ...  highwaympg     price
# wheelbase          1.000000   0.874587  ...   -0.544082  0.577816
# carlength          0.874587   1.000000  ...   -0.704662  0.682920
# carwidth           0.795144   0.841118  ...   -0.677218  0.759325
# carheight          0.589435   0.491029  ...   -0.107358  0.119336
# curbweight         0.776386   0.877728  ...   -0.797465  0.835305
# enginesize         0.569329   0.683360  ...   -0.677470  0.874145
# boreratio          0.488750   0.606454  ...   -0.587012  0.553173
# stroke             0.160959   0.129533  ...   -0.043931  0.079443
# compressionratio   0.249786   0.158414  ...    0.265201  0.067984
# horsepower         0.353294   0.552623  ...   -0.770544  0.808139
# peakrpm           -0.360469  -0.287242  ...   -0.054275 -0.085267
# citympg           -0.470414  -0.670909  ...    0.971337 -0.685751
# highwaympg        -0.544082  -0.704662  ...    1.000000 -0.697599
# ...

# %%
def correlation(dataframe,threshold):
  c_corr = set()
  corr_matrix = dataframe.corr()
  for col in range(len(corr_matrix.columns)):
    for corr in range(col):
      if abs(corr_matrix.iloc[col,corr]) > threshold:
        c_name = corr_matrix.columns[col]
        c_corr.add(c_name)
  return c_corr

# %%
corr_cols = correlation(df.iloc[:,:-1],0.50)
corr_cols
# Out:
# {'boreratio',
#  'carheight',
#  'carlength',
#  'carwidth',
#  'citympg',
#  'curbweight',
#  'enginesize',
#  'highwaympg',
#  'horsepower'}

# %% [markdown]
# VSLORES ATIPICOS

# %%
sns.boxplot(data=df)

# %%
sns.boxplot(x=df['horsepower'])

# %%
sns.boxplot(x=df['enginesize'])

# %%
sns.distplot(df['price'])
dataframe['price'].describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# DISPERSION
#
# PRECIO POTENCIA

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['horsepower'], df['price'])
ax.set_xlabel('horsepower')
ax.set_ylabel('price')
plt.show()

# %% [markdown]
# DIVIDIR EN TRAIN Y TEST

# %%
def catego(df):
   categori_c = []
   for c in f:
      if df[c].dtype != 'object':
           categori_c.append(c)
   return categori_c

n = categorical(df)
ns = df.filter(items=numero) 
numero
# Out:
# ['doornumber',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'cylindernumber',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %% [markdown]
# regesion lineal

# %%
df_x = numeros[['wheelbase','carlength','carwidth','carheight','curbweight','enginesize','boreratio','stroke','compressionratio','horsepower','peakrpm','citympg', 'highwaympg']]
df_y = numeros['price']


plt.plot(df_y,df_x,'b')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Regresión Lineal")
plt.show()

x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size=0.2, random_state=1234)
x_train
# Out:
#      wheelbase  carlength  carwidth  ...  peakrpm  citympg  highwaympg
# 97        94.5      170.2      63.8  ...   5200.0     31.0        37.0
# 198      104.3      188.8      67.2  ...   5100.0     17.0        22.0
# 51        93.1      159.1      64.2  ...   5000.0     31.0        38.0
# 63        98.8      177.8      66.5  ...   4650.0     36.0        42.0
# 74       112.0      199.2      72.0  ...   4500.0     14.0        16.0
# ..         ...        ...       ...  ...      ...      ...         ...
# 152       95.7      158.7      63.6  ...   4800.0     31.0        38.0
# 116      107.9      186.7      68.4  ...   4150.0     28.0        33.0
# 53        93.1      166.8      64.2  ...   5000.0     31.0        38.0
# 38        96.5      167.5      65.2  ...   5800.0     27.0        33.0
# 47       113.0      199.6      69.6  ...   4750.0     15.0        19.0
#
# [164 rows x 13 columns]

# %%
model = LinearRegression()
model.fit(x_train,y_train)

y_hat = model.predict(x_test)
acc = r2_score(y_test, y_hat)
print("Accuracy: %.2f" % acc)

dump(model,"model.joblib")
# Out:
# Accuracy: 0.60
# ['model.joblib']
